# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import scipy.stats as st 
from scipy.stats import linregress 
import datetime

# %%
# Read data from each year file
data_2007=pd.read_csv("Resources/Crime_Data_2007.csv")
data_2008=pd.read_csv("Resources/Crime_Data_2008.csv")
data_2009=pd.read_csv("Resources/Crime_Data_2009.csv")
data_2010=pd.read_csv("Resources/Crime_Data_2010.csv")
data_2011=pd.read_csv("Resources/Crime_Data_2011.csv")
data_2012=pd.read_csv("Resources/Crime_Data_2012.csv")
data_2013=pd.read_csv("Resources/Crime_Data_2013.csv")
data_2014=pd.read_csv("Resources/Crime_Data_2014.csv")
data_2015=pd.read_csv("Resources/Crime_Data_2015.csv")
data_2016=pd.read_csv("Resources/Crime_Data_2016_39.csv")
data_2017=pd.read_csv("Resources/Crime_Data_2017_9.csv")

# data_2016.head()
# Out:
# C:\Users\HM\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Create DataFrames of each year file
df_2017 = pd.DataFrame(data_2017)
df_2016 = pd.DataFrame(data_2016)
df_2015 = pd.DataFrame(data_2015)
df_2014 = pd.DataFrame(data_2014)
df_2013 = pd.DataFrame(data_2013)
df_2017
# Out:
#       INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0        80-16-111411  2017-01-01 08:24:55  2016-12-30 21:00:00
# 1        80-17-000033  2017-01-01 05:20:56  2016-12-31 18:30:00
# 2        80-17-000025  2017-01-01 00:57:00  2017-01-01 00:30:00
# 3        80-17-000005  2017-01-01 00:20:00  2017-01-01 00:01:00
# 4        80-17-000037  2017-01-01 00:35:00  2017-01-01 00:15:00
# ...               ...                  ...                  ...
# 81978    80-17-055092  2017-07-08 18:53:00  2017-07-08 18:53:00
# 81979    80-17-056407  2017-07-13 12:57:00  2017-07-10 15:30:00
# 81980    80-17-054252  2017-07-06 03:13:00  2017-07-06 03:13:00
# 81981    80-17-056453  2017-07-13 15:13:00  2017-07-13 07:15:00
# 81982    80-17-056446  2017-07-13 14:58:00  2017-07-11 14:00:00
#
#                                     UOR_DESC                CRIME_TYPE  \
# 0            TBUT OR DISP ALL OTHERS <  $500             THEFT/LARCENY
# ...

# %%
data_merge= pd.concat([data_2017, data_2016, df_2015, df_2014, df_2013])
data_merge.head()
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-16-111411  2017-01-01 08:24:55  2016-12-30 21:00:00
# 1    80-17-000033  2017-01-01 05:20:56  2016-12-31 18:30:00
# 2    80-17-000025  2017-01-01 00:57:00  2017-01-01 00:30:00
# 3    80-17-000005  2017-01-01 00:20:00  2017-01-01 00:01:00
# 4    80-17-000037  2017-01-01 00:35:00  2017-01-01 00:15:00
#
#                                 UOR_DESC              CRIME_TYPE NIBRS_CODE  \
# 0        TBUT OR DISP ALL OTHERS <  $500           THEFT/LARCENY        23H
# 1  TBUT OR DISP CONTENTS FROM VEH < $500  VEHICLE BREAK-IN/THEFT        23F
# 2    ASSAULT - 4TH DEGREE (MINOR INJURY)                 ASSAULT        13B
# 3           CRIMINAL MISCHIEF-3RD DEGREE               VANDALISM        290
# 4           CRIMINAL MISCHIEF-3RD DEGREE               VANDALISM        290
#
#   UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT            PREMISE_TYPE  \
# ...

# %%
# read_file= pd.read_csv("Resources/datasets_2515_4202_Health_AnimalBites.csv")
# read_file.head()

# %%
#converting to datatime to be able to extrect year, month, days, and hours 
# data_merge["formatted_date"]= pd.to_datetime(data_merge.iloc[:,2], errors="coerce")
# data_merge.head()
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-16-111411  2017-01-01 08:24:55  2016-12-30 21:00:00
# 1    80-17-000033  2017-01-01 05:20:56  2016-12-31 18:30:00
# 2    80-17-000025  2017-01-01 00:57:00  2017-01-01 00:30:00
# 3    80-17-000005  2017-01-01 00:20:00  2017-01-01 00:01:00
# 4    80-17-000037  2017-01-01 00:35:00  2017-01-01 00:15:00
#
#                                 UOR_DESC              CRIME_TYPE NIBRS_CODE  \
# 0        TBUT OR DISP ALL OTHERS <  $500           THEFT/LARCENY        23H
# 1  TBUT OR DISP CONTENTS FROM VEH < $500  VEHICLE BREAK-IN/THEFT        23F
# 2    ASSAULT - 4TH DEGREE (MINOR INJURY)                 ASSAULT        13B
# 3           CRIMINAL MISCHIEF-3RD DEGREE               VANDALISM        290
# 4           CRIMINAL MISCHIEF-3RD DEGREE               VANDALISM        290
#
#   UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT            PREMISE_TYPE  \
# ...

# %%
year_data=data_merge.loc[(data_merge.iloc[:,2]>= "2013-01-01 00:00:00") & (data_merge.iloc[:,2] <= "2017-12-31 00:00:00")]
year_data
# Out:
#       INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0        80-16-111411  2017-01-01 08:24:55  2016-12-30 21:00:00
# 1        80-17-000033  2017-01-01 05:20:56  2016-12-31 18:30:00
# 2        80-17-000025  2017-01-01 00:57:00  2017-01-01 00:30:00
# 3        80-17-000005  2017-01-01 00:20:00  2017-01-01 00:01:00
# 4        80-17-000037  2017-01-01 00:35:00  2017-01-01 00:15:00
# ...               ...                  ...                  ...
# 77122    80-13-072813  2013-09-23 14:01:00  2013-09-18 14:01:00
# 77123    80-13-027653  2013-04-19 23:32:00  2013-04-19 15:00:00
# 77124    80-13-016472  2013-03-08 14:13:00  2013-01-01 00:00:00
# 77125    80-13-090856  2013-11-25 17:00:00  2013-11-25 07:50:00
# 77126    80-13-011253  2013-02-15 09:19:00  2013-02-15 07:15:00
#
#                                     UOR_DESC              CRIME_TYPE  \
# 0            TBUT OR DISP ALL OTHERS <  $500           THEFT/LARCENY
# ...

# %%
year_data.to_csv('crimedata.csv')

# %%
#selecting the needed columns using the loc function
# Animal_Bites_Table=lf.iloc[:,[16,1,2,3,4,7]]
# Animal_Bites_Table

# %%
tf= pd.DataFrame(Animal_Bites_Table)
rn= tf.rename(columns={"bite_year":"years","SpeciesIDDesc":"species","BreedIDDesc":"Breed","GenderIDDesc":"Gender","color":"Color","victim_zip":"ZipCode"})
kf= rn.loc[(rn.iloc[:,0]>=2007.0) & (rn.iloc[:,0])<=2017.0]
kf

# %%
#retrieving  the the number and type of animal from the dataframe 
data_test=kf["species"].value_counts()
data_test

# %%
#pie chart 
explode=(.1,.1,1,0,.4,.7)
colors=("red","lightcoral","green","lightskyblue","orange","yellow" )
data_test.head(6).plot.pie(colors=colors, autopct="%.1f%%", explode=explode, startangle=140, figsize=(5,5))
plt.show()

# %%
#accordintg to our Data we can say that dogs are more likely to bite human, they represent 79.2% of all cases follow by cats with 17.7%
#we also negligeable cases like FERRET,RABBIT,SKUNK

# %%
#find the area location with more bites
#grouping and sorting data 
Animal_Bites_grouped= Animal_Bites_Table.groupby(["victim_zip"])["SpeciesIDDesc"].count().reset_index()
Animal_Bites_sort= Animal_Bites_grouped.sort_values(["SpeciesIDDesc"], ascending=False)
Animal_Bites_sort

# %%
#Find the Zipcode with the most bite by using the loc function 
most_bite_zip= Animal_Bites_sort.loc[Animal_Bites_sort["SpeciesIDDesc"]==371]
#convert to a dataframe visualisation 
visual_mbz= pd.DataFrame(most_bite_zip)
visual_mbz_rename=visual_mbz.rename(columns={"SpeciesIDDesc":"Number of Bites (max)"})
visual_mbz_rename.reset_index()

# %%
#
group_Breed_zip= Animal_Bites_Table.groupby(["BreedIDDesc"])["victim_zip"].count().reset_index()
group_Breed_zip_sort= group_Breed_zip.sort_values(["victim_zip"],ascending=False)
bite_per_breed= group_Breed_zip_sort.set_index("BreedIDDesc")
bite_per_breed

# %%
#barplot
bite_per_breed.head(20).plot(kind= "bar",color="b", figsize=(20,5))
plt.title("Number of bite per dog breed")
plt.xlabel("Dog Breed")
plt.ylabel("number of Bites")
plt.show()
# As we can see, the number of bites is in some way related to the breed of animals 
# therefore if our hypothesis comes to be  true, then we will conclude that one breed is more likely to be prone to violence than 
#another one if exposed at a violent environment

# %%
#Trying to extract years and slct the proper range

# %%
Animal_Bites_per_year= read_file.groupby(["bite_date"])["SpeciesIDDesc"].count().reset_index()
A_B_P_Y= list(Animal_Bites_per_year["bite_date"])
year=[]
for y in A_B_P_Y:
    year.append(y[:4])
print(year)

# %%
#conver to dataframe
bite_y["years"]=pd.DataFrame(year)

count_bites_year= bite_y.groupby("years")
year_bite_count= count_bites_year.count().reset_index()
year_bite_count

# %%
year_bite_count.info()
