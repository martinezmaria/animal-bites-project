# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# %%
animal_bites_file = pd.read_csv('animalbites.csv')
df = pd.DataFrame(animal_bites_file)
df
# Out:
#                 bite_date SpeciesIDDesc      BreedIDDesc GenderIDDesc  \
# 0     1985-05-05 00:00:00           DOG              NaN       FEMALE
# 1     1986-02-12 00:00:00           DOG              NaN      UNKNOWN
# 2     1987-05-07 00:00:00           DOG              NaN      UNKNOWN
# 3     1988-10-02 00:00:00           DOG              NaN         MALE
# 4     1989-08-29 00:00:00           DOG              NaN       FEMALE
# ...                   ...           ...              ...          ...
# 8998  2017-09-05 00:00:00           DOG              NaN          NaN
# 8999  2017-09-07 00:00:00           DOG       POMERANIAN         MALE
# 9000  2017-09-07 00:00:00           DOG  LABRADOR RETRIV         MALE
# 9001  2017-09-07 00:00:00           DOG  LABRADOR RETRIV       FEMALE
# 9002  2017-09-07 00:00:00           DOG            BOXER          NaN
#
#            color  vaccination_yrs     vaccination_date victim_zip  \
# 0     LIG. BROWN              1.0  1985-06-20 00:00:00      40229
# 1      BRO & BLA              NaN                  NaN      40218
# 2            NaN              NaN                  NaN      40219
# 3      BLA & BRO              NaN                  NaN        NaN
# 4        BLK-WHT              NaN                  NaN        NaN
# ...          ...              ...                  ...        ...
# 8998         NaN              NaN                  NaN      40243
# 8999         RED              NaN                  NaN      40204
# 9000       BROWN              NaN                  NaN      47130
# 9001     BLK WHT              NaN                  NaN      40229
# 9002     BRN BLK              NaN                  NaN      40229
#
#      AdvIssuedYNDesc WhereBittenIDDesc      quarantine_date DispositionIDDesc  \
# 0                 NO              BODY  1985-05-05 00:00:00           UNKNOWN
# 1                 NO              BODY  1986-02-12 00:00:00           UNKNOWN
# 2                 NO              BODY  1990-05-07 00:00:00           UNKNOWN
# 3                 NO              BODY  1990-10-02 00:00:00           UNKNOWN
# 4                 NO              BODY                  NaN           UNKNOWN
# ...              ...               ...                  ...               ...
# 8998             NaN           UNKNOWN                  NaN               NaN
# 8999             NaN              HEAD                  NaN               NaN
# 9000             NaN           UNKNOWN                  NaN               NaN
# 9001             NaN              BODY                  NaN               NaN
# 9002             NaN              BODY                  NaN               NaN
#
#      head_sent_date release_date ResultsIDDesc
# 0               NaN          NaN       UNKNOWN
# 1               NaN          NaN       UNKNOWN
# 2               NaN          NaN       UNKNOWN
# 3               NaN          NaN       UNKNOWN
# 4               NaN          NaN       UNKNOWN
# ...             ...          ...           ...
# 8998            NaN          NaN           NaN
# 8999            NaN          NaN           NaN
# 9000            NaN          NaN           NaN
# 9001            NaN          NaN           NaN
# 9002            NaN          NaN           NaN
#
# [9003 rows x 15 columns]

# %%
df["formatted_date"]= pd.to_datetime(df.iloc[:,0], errors="coerce")
df.head()
# Out:
#              bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0  1985-05-05 00:00:00           DOG         NaN       FEMALE  LIG. BROWN
# 1  1986-02-12 00:00:00           DOG         NaN      UNKNOWN   BRO & BLA
# 2  1987-05-07 00:00:00           DOG         NaN      UNKNOWN         NaN
# 3  1988-10-02 00:00:00           DOG         NaN         MALE   BLA & BRO
# 4  1989-08-29 00:00:00           DOG         NaN       FEMALE     BLK-WHT
#
#    vaccination_yrs     vaccination_date victim_zip AdvIssuedYNDesc  \
# 0              1.0  1985-06-20 00:00:00      40229              NO
# 1              NaN                  NaN      40218              NO
# 2              NaN                  NaN      40219              NO
# 3              NaN                  NaN        NaN              NO
# 4              NaN                  NaN        NaN              NO
#
#   WhereBittenIDDesc      quarantine_date DispositionIDDesc head_sent_date  \
# 0              BODY  1985-05-05 00:00:00           UNKNOWN            NaN
# 1              BODY  1986-02-12 00:00:00           UNKNOWN            NaN
# 2              BODY  1990-05-07 00:00:00           UNKNOWN            NaN
# 3              BODY  1990-10-02 00:00:00           UNKNOWN            NaN
# 4              BODY                  NaN           UNKNOWN            NaN
#
#   release_date ResultsIDDesc formatted_date
# 0          NaN       UNKNOWN     1985-05-05
# 1          NaN       UNKNOWN     1986-02-12
# 2          NaN       UNKNOWN     1987-05-07
# 3          NaN       UNKNOWN     1988-10-02
# 4          NaN       UNKNOWN     1989-08-29

# %%
narrowed_df = df[['formatted_date', 'SpeciesIDDesc', 'BreedIDDesc', 'GenderIDDesc', 'victim_zip', 'WhereBittenIDDesc']]
narrowed_df
# Out:
#      formatted_date SpeciesIDDesc      BreedIDDesc GenderIDDesc victim_zip  \
# 0        1985-05-05           DOG              NaN       FEMALE      40229
# 1        1986-02-12           DOG              NaN      UNKNOWN      40218
# 2        1987-05-07           DOG              NaN      UNKNOWN      40219
# 3        1988-10-02           DOG              NaN         MALE        NaN
# 4        1989-08-29           DOG              NaN       FEMALE        NaN
# ...             ...           ...              ...          ...        ...
# 8998     2017-09-05           DOG              NaN          NaN      40243
# 8999     2017-09-07           DOG       POMERANIAN         MALE      40204
# 9000     2017-09-07           DOG  LABRADOR RETRIV         MALE      47130
# 9001     2017-09-07           DOG  LABRADOR RETRIV       FEMALE      40229
# 9002     2017-09-07           DOG            BOXER          NaN      40229
#
#      WhereBittenIDDesc
# 0                 BODY
# 1                 BODY
# 2                 BODY
# 3                 BODY
# 4                 BODY
# ...                ...
# 8998           UNKNOWN
# 8999              HEAD
# 9000           UNKNOWN
# 9001              BODY
# 9002              BODY
#
# [9003 rows x 6 columns]

# %%
data = narrowed_df.rename(columns={"formatted_date": "Date", "SpeciesIDDesc": "Animal Type",
                                  "BreedIDDesc": "Breed", "GenderIDDesc": "Gender",
                                  "victim_zip": "Victim Zip Code", "WhereBittenIDDesc": "Where Bitten"})

data
# Out:
#            Date Animal Type            Breed   Gender Victim Zip Code  \
# 0    1985-05-05         DOG              NaN   FEMALE           40229
# 1    1986-02-12         DOG              NaN  UNKNOWN           40218
# 2    1987-05-07         DOG              NaN  UNKNOWN           40219
# 3    1988-10-02         DOG              NaN     MALE             NaN
# 4    1989-08-29         DOG              NaN   FEMALE             NaN
# ...         ...         ...              ...      ...             ...
# 8998 2017-09-05         DOG              NaN      NaN           40243
# 8999 2017-09-07         DOG       POMERANIAN     MALE           40204
# 9000 2017-09-07         DOG  LABRADOR RETRIV     MALE           47130
# 9001 2017-09-07         DOG  LABRADOR RETRIV   FEMALE           40229
# 9002 2017-09-07         DOG            BOXER      NaN           40229
#
#      Where Bitten
# 0            BODY
# 1            BODY
# 2            BODY
# 3            BODY
# 4            BODY
# ...           ...
# 8998      UNKNOWN
# 8999         HEAD
# 9000      UNKNOWN
# 9001         BODY
# 9002         BODY
#
# [9003 rows x 6 columns]

# %%
# removing null values to avoid errors 
data.dropna(inplace = True)

# %%
# start stop and step variables
start, stop, step = 0, -6, 1

# converting to string data type 
data["Date"]= data["Date"].astype(str) 

# slicing till month element 
data["Year"]= data["Date"].str.slice(start, stop, step) 

# display 
data
# Out:
#             Date Animal Type            Breed   Gender Victim Zip Code  \
# 1153  2010-12-24         DOG    GERM SHEPHERD  UNKNOWN           40291
# 1202  2011-01-11         DOG        DACHSHUND     MALE           40207
# 1208  2011-01-16         DOG         PIT BULL  UNKNOWN           40216
# 1244  2011-01-29         DOG         SHIH TZU     MALE           40223
# 1252  2011-02-04         DOG         SHIH TZU   FEMALE           40229
# ...          ...         ...              ...      ...             ...
# 8995  2017-09-04         DOG        BLACK LAB     MALE           40229
# 8997  2017-09-06         DOG       CHICHAUHUA   FEMALE           40206
# 8999  2017-09-07         DOG       POMERANIAN     MALE           40204
# 9000  2017-09-07         DOG  LABRADOR RETRIV     MALE           47130
# 9001  2017-09-07         DOG  LABRADOR RETRIV   FEMALE           40229
#
#      Where Bitten  Year
# 1153         BODY  2010
# 1202         BODY  2011
# 1208         BODY  2011
# 1244         BODY  2011
# 1252         BODY  2011
# ...           ...   ...
# 8995         BODY  2017
# 8997         HEAD  2017
# 8999         HEAD  2017
# 9000      UNKNOWN  2017
# 9001         BODY  2017
#
# [2479 rows x 7 columns]

# %%
data = data.drop(columns='Date')
data
# Out:
#      Animal Type            Breed   Gender Victim Zip Code Where Bitten  Year
# 1153         DOG    GERM SHEPHERD  UNKNOWN           40291         BODY  2010
# 1202         DOG        DACHSHUND     MALE           40207         BODY  2011
# 1208         DOG         PIT BULL  UNKNOWN           40216         BODY  2011
# 1244         DOG         SHIH TZU     MALE           40223         BODY  2011
# 1252         DOG         SHIH TZU   FEMALE           40229         BODY  2011
# ...          ...              ...      ...             ...          ...   ...
# 8995         DOG        BLACK LAB     MALE           40229         BODY  2017
# 8997         DOG       CHICHAUHUA   FEMALE           40206         HEAD  2017
# 8999         DOG       POMERANIAN     MALE           40204         HEAD  2017
# 9000         DOG  LABRADOR RETRIV     MALE           47130      UNKNOWN  2017
# 9001         DOG  LABRADOR RETRIV   FEMALE           40229         BODY  2017
#
# [2479 rows x 6 columns]

# %%
data = data.sort_values('Gender')
data
# Out:
#      Animal Type            Breed   Gender Victim Zip Code Where Bitten  Year
# 9001         DOG  LABRADOR RETRIV   FEMALE           40229         BODY  2017
# 7856         DOG      BULLMASTIFF   FEMALE           40219         BODY  2016
# 4891         DOG         PIT BULL   FEMALE           40245         BODY  2013
# 4914         DOG         BULL DOG   FEMALE           40220         BODY  2013
# 7852         DOG   GOLD RETRIEVER   FEMALE           40299         HEAD  2016
# ...          ...              ...      ...             ...          ...   ...
# 7655         DOG    SIBERAN HUSKY  UNKNOWN           40217         BODY  2016
# 7656         DOG            BOXER  UNKNOWN           40217         BODY  2016
# 7658         DOG           COLLIE  UNKNOWN           45142         BODY  2016
# 8084         DOG   BOSTON TERRIER  UNKNOWN           40291      UNKNOWN  2016
# 1153         DOG    GERM SHEPHERD  UNKNOWN           40291         BODY  2010
#
# [2479 rows x 6 columns]

# %%
animals_types =data['Animal Type'].value_counts()
animals_types
# Out:
# DOG    2477
# CAT       2
# Name: Animal Type, dtype: int64

# %%
animals_gen=data['Gender'].value_counts()
animals_gen
# Out:
# MALE       1653
# FEMALE      764
# UNKNOWN      62
# Name: Gender, dtype: int64

# %%
animals_desc=data['Breed'].value_counts()
animals_desc.head()
# Out:
# PIT BULL           707
# GERM SHEPHERD      218
# LABRADOR RETRIV    178
# BOXER              124
# CHICHAUHUA         109
# Name: Breed, dtype: int64

# %%
bite_desc=data['Where Bitten'].value_counts()
bite_desc
# Out:
# BODY       1783
# HEAD        457
# UNKNOWN     239
# Name: Where Bitten, dtype: int64

# %%
year_data = year_data.drop(year_data[(year_data.Year < "2007") & (year_data.Year > "2017")].index, inplace=False)
year_data.sort_values('Year')
# Out:
#      Animal Type          Breed   Gender Victim Zip Code Where Bitten  Year
# 8570         DOG    RAT TERRIER   FEMALE           40299      UNKNOWN  1952
# 7580         DOG       PIT BULL  UNKNOWN           40291         BODY  1995
# 8816         DOG       PIT BULL   FEMALE           40229         BODY  2001
# 1153         DOG  GERM SHEPHERD  UNKNOWN           40291         BODY  2010
# 1716         DOG  GERM SHEPHERD     MALE           40219         BODY  2011
# ...          ...            ...      ...             ...          ...   ...
# 8265         DOG       PIT BULL     MALE           40213         BODY  2017
# 8261         DOG          BOXER     MALE           40218         BODY  2017
# 8473         DOG       PIT BULL     MALE           40291         BODY  2017
# 3012         DOG       PIT BULL     MALE           40272         BODY  2021
# 6505         DOG      DACHSHUND     MALE           40229         BODY  2201
#
# [2479 rows x 6 columns]

# %%
year_group = year_data.groupby("Year").count()
year_group
# Out:
#       Animal Type  Breed  Gender  Victim Zip Code  Where Bitten
# Year
# 1952            1      1       1                1             1
# 1995            1      1       1                1             1
# 2001            1      1       1                1             1
# 2010            1      1       1                1             1
# 2011          322    322     322              322           322
# 2012          279    279     279              279           279
# 2013          213    213     213              213           213
# 2014          207    207     207              207           207
# 2015          484    484     484              484           484
# 2016          553    553     553              553           553
# 2017          415    415     415              415           415
# 2021            1      1       1                1             1
# 2201            1      1       1                1             1
